# %% [markdown]
# ## Exploring Descriptive Statistics

# %% [markdown]
# Use the following dataset to answer the questions about the **diamonds** dataset.

# %%
# Run this cell without changes
import pandas as pd

# %%
# !ls ../pandas-202/
# Out:
# diamonds.csv index.ipynb

# %%
# Run this cell without changes
df = pd.read_csv('../pandas-202/diamonds.csv')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# **1) What are the mean carat and the median carat for the each group of color in this dataset?**

# %%
df.groupby("color")["carat"].median().reset_index()
# Out:
#   color  carat
# 0     D   0.53
# 1     E   0.53
# 2     F   0.70
# 3     G   0.70
# 4     H   0.90
# 5     I   1.00
# 6     J   1.11

# %% [markdown]
# **Give me the average price for each clarity**

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.groupby("clarity")["price"].mean().reset_index()
# Out:
#   clarity        price
# 0      I1  3924.168691
# 1      IF  2864.839106
# 2     SI1  3996.001148
# 3     SI2  5063.028606
# 4     VS1  3839.455391
# 5     VS2  3924.989395
# 6    VVS1  2523.114637
# 7    VVS2  3283.737071

# %% [markdown]
# **cut	color	clarity	 avg price, depth**

# %%
df.groupby(["cut","color","clarity"])[["price","depth"]].mean()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# In your own words, how are the mean and median related to each other and what do these values tell us about the distribution of the variable 'carat'

# %% [markdown]
# **2) Arrange the table so that the diamonds with the highest carats are listed first.**

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.sort_values(["carat"], ascending = False).head()
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17

# %% [markdown]
# **BONUS 1: Use the seaborn library to make a scatter plot between carat and depth, carat and table, carat and price. Use the hue argument to group by either color or cut**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.6)
k_depth = sns.scatterplot(x="carat", y="depth",
                     hue="cut", data=df)

# %% [markdown]
# **BONUS 2: Calculate the correlation coeffecient between each continuous variable in this dataset.**

# %%
# Your code here!

# %% [markdown]
# **BONUS 3: Interpret each correlation coeffecient. Refer to your READMEs, Labs, or external literature if needed!**

# %% [markdown]
# Your answer here!
